# %%
# Cargar librerías necesarias
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.utils import resample

# %%
# Cargar el DataFrame principal desde un archivo CSV
import pandas as pd
# Cargar el dataset
df = pd.read_csv(r'../data/dataset.csv')
df.head()
# Out:
#     age   bmi  gender  hypertension  heart_disease  stroke
# 0  67.0  36.6     0.0           0.0            1.0     1.0
# 1  80.0  32.5     0.0           0.0            1.0     1.0
# 2  49.0  34.4     1.0           0.0            0.0     1.0
# 3  79.0  24.0     1.0           1.0            0.0     1.0
# 4  81.0  29.0     0.0           0.0            0.0     1.0

# %%
print(df.columns.tolist())
# Out:
# ['age', 'bmi', 'gender', 'hypertension', 'heart_disease', 'stroke']

# %%
print(df.head())
# Out:
#     age   bmi  gender  hypertension  heart_disease  stroke
# 0  67.0  36.6     0.0           0.0            1.0     1.0
# 1  80.0  32.5     0.0           0.0            1.0     1.0
# 2  49.0  34.4     1.0           0.0            0.0     1.0
# 3  79.0  24.0     1.0           1.0            0.0     1.0
# 4  81.0  29.0     0.0           0.0            0.0     1.0

# %%
print(df.dtypes)
# Out:
# age              float64
# bmi              float64
# gender           float64
# hypertension     float64
# heart_disease    float64
# stroke           float64
# dtype: object
